# %%
import json
import pandas as pd
from textblob import TextBlob

def read_json(json_file: str)->list:
    """
    json file reader to open and read json files into a list
    Args:
    -----
    json_file: str - path of a json file
    
    Returns
    -------
    length of the json file and a list of json
    """
    
    tweets_data = []
    for tweets in open(json_file,'r'):
        tweets_data.append(json.loads(tweets))
    
    
    return len(tweets_data), tweets_data

# %%
if __name__ == "__main__":
    # required column to be generated you should be creative and add more features
    columns = ['created_at', 'source', 'original_text','clean_text', 'sentiment','polarity','subjectivity', 'lang', 'favorite_count', 'retweet_count', 
    'original_author', 'screen_count', 'followers_count','friends_count','possibly_sensitive', 'hashtags', 'user_mentions', 'place', 'place_coord_boundaries']
    _, tweet_list = read_json("../covid19.json")
    tweet = TweetDfExtractor(tweet_list)
    tweet_df = tweet.get_tweet_df() 

    # use all defined functions to generate a dataframe with the specified columns above

# %%
def find_statuses_count(self)->list:
        statuses_count

# %%
df = pd.read_json(r"C:\Users\sam\Desktop\test\data\Economic_Twitter_Data\Economic_Twitter_Data.json", lines=True)
df.head()
#df[['user', 'statuses_count']]
# Out:
#                  created_at                   id               id_str  \
# 0 2022-04-22 22:20:18+00:00  1517629396575784961  1517629396575784960
# 1 2022-04-22 22:19:16+00:00  1517629134012399616  1517629134012399616
# 2 2022-04-22 22:17:28+00:00  1517628682659106822  1517628682659106816
# 3 2022-04-22 22:17:20+00:00  1517628647892561924  1517628647892561920
# 4 2022-04-22 22:13:15+00:00  1517627621135237127  1517627621135237120
#
#                                                 text  truncated  \
# 0  RT @nikitheblogger: Irre: Annalena Baerbock sa...      False
# 1  RT @sagt_mit: Merkel schaffte es in 1 Jahr 1 M...      False
# 2  RT @Kryptonoun: @WRi007 Pharma in Lebensmittel...      False
# 3  RT @WRi007: Die #Deutschen sind ein braves Vol...      False
# 4  RT @RolandTichy: Baerbock verkündet mal so neb...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
df[['user', 'text']]
# Out:
#                                                     user  \
# 0      {'id': 1487174445248692233, 'id_str': '1487174...
# 1      {'id': 1487174445248692233, 'id_str': '1487174...
# 2      {'id': 1487174445248692233, 'id_str': '1487174...
# 3      {'id': 1487174445248692233, 'id_str': '1487174...
# 4      {'id': 1487174445248692233, 'id_str': '1487174...
# ...                                                  ...
# 24620  {'id': 1357448202, 'id_str': '1357448202', 'na...
# 24621  {'id': 1357448202, 'id_str': '1357448202', 'na...
# 24622  {'id': 1357448202, 'id_str': '1357448202', 'na...
# 24623  {'id': 1357448202, 'id_str': '1357448202', 'na...
# 24624  {'id': 1357448202, 'id_str': '1357448202', 'na...
#
#                                                     text
# 0      RT @nikitheblogger: Irre: Annalena Baerbock sa...
# 1      RT @sagt_mit: Merkel schaffte es in 1 Jahr 1 M...
# 2      RT @Kryptonoun: @WRi007 Pharma in Lebensmittel...
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# retweeted_status
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# extended_entities
# possibly_sensitive
# quoted_status_id
# quoted_status_id_str
# quoted_status
# withheld_in_countries

# %%
df[['retweeted_status', 'extended_entities', 'text']]
# Out:
#                                         retweeted_status extended_entities  \
# 0      {'created_at': 'Fri Apr 22 14:38:54 +0000 2022...               NaN
# 1      {'created_at': 'Thu Apr 21 15:44:41 +0000 2022...               NaN
# 2      {'created_at': 'Thu Apr 21 09:46:16 +0000 2022...               NaN
# 3      {'created_at': 'Thu Apr 21 05:12:42 +0000 2022...               NaN
# 4      {'created_at': 'Thu Apr 21 06:45:59 +0000 2022...               NaN
# ...                                                  ...               ...
# 24620  {'created_at': 'Fri Apr 22 08:43:20 +0000 2022...               NaN
# 24621  {'created_at': 'Fri Apr 22 12:07:18 +0000 2022...               NaN
# 24622  {'created_at': 'Fri Apr 22 05:38:40 +0000 2022...               NaN
# 24623  {'created_at': 'Fri Apr 22 11:21:30 +0000 2022...               NaN
# 24624  {'created_at': 'Fri Apr 22 13:46:22 +0000 2022...               NaN
#
#                                                     text
# ...

# %%
df[['favorite']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-7ff87ad797a7> in <module>
# ----> 1 df[['favorite']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ...

# %%
file = read_json(r"C:\Users\sam\Desktop\test\data\Economic_Twitter_Data\Economic_Twitter_Data.json")
print(file[1][0])
# Out:
# {'created_at': 'Fri Apr 22 22:20:18 +0000 2022', 'id': 1517629396575784961, 'id_str': '1517629396575784961', 'text': 'RT @nikitheblogger: Irre: Annalena Baerbock sagt, es bricht ihr das Herz, dass man nicht bedingungslos schwere Waffen liefert.\nMir bricht e…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'nikitheblogger', 'name': 'Neverforgetniki', 'id': 809188392089092097, 'id_str': '809188392089092097', 'indices': [3, 18]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1487174445248692233, 'id_str': '1487174445248692233', 'name': 'MC', 'screen_name': 'McMc74078966', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count
# ...

# %%
import pandas as pd    
import json

file = r"C:\Users\sam\Desktop\test\data\Economic_Twitter_Data\Economic_Twitter_Data.json"
with open(file, 'r') as f:
    data = json.load(f)
rows = data[0]
df = pd.DataFrame(rows)
